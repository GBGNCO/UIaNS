# %% [markdown]
# <a href="https://colab.research.google.com/github/GBGNCO/UIaNS/blob/main/GencoFodor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mtcnn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 41.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3cadbd9a-267c-47e0-b4e5-a7c4e3cf7fd1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3cadbd9a-267c-47e0-b4e5-a7c4e3cf7fd1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import required libraries
import cv2
import matplotlib.pyplot as plt
from mtcnn import MTCNN
import tensorflow as tf

# Load an image for face detection
def load_image(phototest):
    """Loads an image from a given path."""
    image = cv2.imread(phototest)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    return image

# Display the image with detected faces
def display_image_with_detections(image, detections):
    """Displays the image with rectangles drawn around detected faces."""
    for detection in detections:
        x, y, width, height = detection['box']
        confidence = detection['confidence']
        # Draw rectangle and label
        cv2.rectangle(image, (x, y), (x + width, y + height), (0, 255, 0), 2)
        cv2.putText(
            image,
            f"{confidence:.2f}",
            (x, y - 10),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.5,
            (0, 255, 0),
            2,
        )

    # Show the result using Matplotlib
    plt.figure(figsize=(8, 8))
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# Main execution flow
def detect_faces(phototest):
    """Detects faces in the given image using MTCNN."""
    # Load the image
    image = load_image(image_path)

    # Initialize the MTCNN model
    detector = MTCNN()

    # Detect faces
    detections = detector.detect_faces(image)

    # Display the results
    display_image_with_detections(image, detections)

# Example usage
if __name__ == "__main__":
    # Upload an image to Google Colab and set its path here
    image_path = "phototest.jpg"  # Replace with your image file
    detect_faces(image_path)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5de24a26-4120-4866-80e7-532c965c9c07" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5de24a26-4120-4866-80e7-532c965c9c07">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import required libraries
import cv2
import matplotlib.pyplot as plt
from mtcnn import MTCNN
import tensorflow as tf

# Load an image for face detection
def load_image(Groupphoto):
    """Loads an image from a given path."""
    image = cv2.imread(Groupphoto)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    return image

# Display the image with detected faces
def display_image_with_detections(image, detections):
    """Displays the image with rectangles drawn around detected faces."""
    for detection in detections:
        x, y, width, height = detection['box']
        confidence = detection['confidence']
        # Draw rectangle and label
        cv2.rectangle(image, (x, y), (x + width, y + height), (0, 255, 0), 2)
        cv2.putText(
            image,
            f"{confidence:.2f}",
            (x, y - 10),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.5,
            (0, 255, 0),
            2,
        )

    # Show the result using Matplotlib
    plt.figure(figsize=(8, 8))
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# Main execution flow
def detect_faces(Groupphoto):
    """Detects faces in the given image using MTCNN."""
    # Load the image
    image = load_image(Groupphoto)

    # Initialize the MTCNN model
    detector = MTCNN()

    # Detect faces
    detections = detector.detect_faces(image)

    # Display the results
    display_image_with_detections(image, detections)

# Example usage
if __name__ == "__main__":
    # Upload an image to Google Colab and set its path here
    image_path = "Groupphoto.jpg"  # Replace with your image file
    detect_faces(image_path)
